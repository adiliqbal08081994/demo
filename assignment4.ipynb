# %%
"""Create a DatetimeIndex that contains each business day of 2015 and use it to index a Series of
random numbers."""
import numpy as np
import pandas as pd
date1 = '2015-01-01'
date2 = '2015-12-31'
a = pd.date_range(date1, date2).tolist()
df=pd.Series(np.random.randint(10,100,365),index=[date])
df=pd.DataFrame(df,columns=['values'])
c=[]
i=1
while 2<3:
    
    c.append('thursday')
    
    i=i+1
    if i==366:
        break
    c.append('friday')
    
    i=i+1
    if i==366:
        break
    c.append('saturday')
    
    i=i+1
    if i==366:
        break
    c.append('sunday')
    
    i=i+1
    if i==366:
        break
    c.append('monday')
    
    i=i+1
    if i==366:
        break
    c.append('tuesday')
    
    i=i+1
    if i==366:
        break
    c.append('wednesday')
    
    i=i+1
    if i==366:
        break
c=pd.Series(c,index=[date])    
df['days']=pd.Series(c,index=[date])
df=pd.DataFrame(df)
import datetime
date=[]
month=[]
for i in range(len(a)):
    start = str(a[i])

    start_date = datetime.datetime.strptime(start, '%Y-%m-%d %H:%M:%S').date()

    date.append((start_date.strftime('%Y-%b-%d')))
    month.append((start_date.strftime('%b')))
month    
df['months']=pd.Series(month,index=[date])

df
# Out:
#              values       days months
# 2015-Jan-01      77   thursday    Jan
# 2015-Jan-02      60     friday    Jan
# 2015-Jan-03      22   saturday    Jan
# 2015-Jan-04      98     sunday    Jan
# 2015-Jan-05      93     monday    Jan
# 2015-Jan-06      58    tuesday    Jan
# 2015-Jan-07      77  wednesday    Jan
# 2015-Jan-08      59   thursday    Jan
# 2015-Jan-09      89     friday    Jan
# 2015-Jan-10      13   saturday    Jan
# 2015-Jan-11      14     sunday    Jan
# 2015-Jan-12      15     monday    Jan
# 2015-Jan-13      20    tuesday    Jan
# 2015-Jan-14      45  wednesday    Jan
# 2015-Jan-15      67   thursday    Jan
# 2015-Jan-16      87     friday    Jan
# 2015-Jan-17      40   saturday    Jan
# 2015-Jan-18      27     sunday    Jan
# 2015-Jan-19      56     monday    Jan
# 2015-Jan-20      57    tuesday    Jan
# 2015-Jan-21      12  wednesday    Jan
# 2015-Jan-22      20   thursday    Jan
# 2015-Jan-23      26     friday    Jan
# 2015-Jan-24      33   saturday    Jan
# ...

# %%
"""Find the sum of the values in s for every Wednesday"""
day=pd.unique(df['days'])
sum_of_wednesday=df.loc[df.days==day[6],['values']]
np.array(sum_of_wednesday)
np.sum(sum_of_wednesday)
# Out:
# values    2884
# dtype: int64

# %%
"""Average For each calendar month"""
x=pd.unique(df['months'])
for i in range(len(x)):
    p=df.loc[df.months==x[i],['values']]
    q=(np.array(p))
    print(x[i])
    print(np.average(q))
# Out:
# Jan
# 46.225806451612904
# Feb
# 49.92857142857143
# Mar
# 51.225806451612904
# Apr
# 59.0
# May
# 50.516129032258064
# Jun
# 56.36666666666667
# Jul
# 56.83870967741935
# Aug
# 51.38709677419355
# Sep
# 55.03333333333333
# Oct
# 51.903225806451616
# Nov
# 54.1
# Dec
# 49.29032258064516

# %%
"""For each group of four consecutive calendar months in s, find the date on which the highest
value occurred."""

x=pd.unique(df['months'])
i=0
while i<=(len(x)-4):
    empty=[]
    emptydf=[]
    f1=df.loc[df.months==x[i],['values']]
    
    empty.append((f1))
    i=i+1
    g1=df.loc[df.months==x[i],['values']]
    
    empty.append((g1))
    i=i+1
    r=df.loc[df.months==x[i],['values']]
    
    empty.append((r))
    i=i+1
    s=df.loc[df.months==x[i],['values']]
    
    empty.append((s))
    i+1
    emptydf.append(max(empty[0]['values']))
    print(max(emptydf))
# Out:
# 98
# 96
# 98

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-379-101a633ccdfa> in <module>
# ----> 1 pd.max(empty)
#
# AttributeError: module 'pandas' has no attribute 'max'

# %%
pwd()
# Out:
# 'C:\\Users\\HP PC'
